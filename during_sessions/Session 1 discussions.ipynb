# %% [markdown]
# # Entiers et `big`

# %%
10**18
# Out:
# syntax: use "^" instead of "**"
# while loading In[1], in expression starting on line 1

# %%
10^18
# Out:
# 1000000000000000000

# %%
10^19
# Out:
# -8446744073709551616

# %%
typeof(ans)
# Out:
# Int64

# %%
typemax(Int64)
# Out:
# 9223372036854775807

# %%
typemin(Int64)
# Out:
# -9223372036854775808

# %%
9223372036854775807 + 1
# Out:
# -9223372036854775808

# %%
bits(9223372036854775807)
# Out:
# "0111111111111111111111111111111111111111111111111111111111111111"

# %%
a = big(10)
# Out:
# 10

# %%
typeof(ans)
# Out:
# BigInt (constructor with 10 methods)

# %%
a = BigInt(10)
# Out:
# 10

# %%
a^20
# Out:
# 100000000000000000000

# %%
int128(10)^20  # Int128(10)
# Out:
# 100000000000000000000

# %%
big(3.5)
# Out:
# 3.5e+00 with 256 bits of precision

# %%
typeof(ans)
# Out:
# BigFloat (constructor with 14 methods)

# %%
BigInt(3.0)
# Out:
# 3

# %%
typeof(ans)
# Out:
# BigInt (constructor with 10 methods)

# %%
floor(3.5)
# Out:
# 3.0

# %%
sqrt(-1)
# Out:
# DomainError
# while loading In[19], in expression starting on line 1
#
#  in sqrt at math.jl:133

# %%
typeof(big(3))
# Out:
# BigInt (constructor with 10 methods)

# %%
typeof(big(3.5))
# Out:
# BigFloat (constructor with 14 methods)

# %%
big
# Out:
# big (generic function with 9 methods)

# %%
methods(big)
# Out:
# # 9 methods for generic function "big":
# big{T,S,UpLo,IsUnit}(A::Triangular{T,S,UpLo,IsUnit}) at linalg/triangular.jl:152
# big{T<:FloatingPoint,N}(x::AbstractArray{T<:FloatingPoint,N}) at abstractarray.jl:299
# big{T<:FloatingPoint,N}(x::AbstractArray{Complex{T<:FloatingPoint},N}) at abstractarray.jl:300
# big{T<:Integer,N}(x::AbstractArray{T<:Integer,N}) at abstractarray.jl:301
# big(n::Integer) at /Users/dsanders/development/julia/base/sysimg.jl:176
# big(x::FloatingPoint) at /Users/dsanders/development/julia/base/sysimg.jl:177
# big(q::Rational{T<:Integer}) at /Users/dsanders/development/julia/base/sysimg.jl:178
# big(z::Complex{T<:Real}) at /Users/dsanders/development/julia/base/sysimg.jl:179
# big(x::MathConst{sym}) at constants.jl:51

# %%
pi
# Out:
# π = 3.1415926535897...

# %%
typeof(pi)
# Out:
# MathConst{:π} (constructor with 1 method)

# %%
π
# Out:
# π = 3.1415926535897...

# %%
big(π)
# Out:
# 3.141592653589793238462643383279502884197169399375105820974944592307816406286198e+00 with 256 bits of precision

# %% [markdown]
# This is an example of **multiple dispatch**

# %%
f(x) = 2x
# Out:
# f (generic function with 1 method)

# %%
f
# Out:
# f (generic function with 1 method)

# %%
f(3)
# Out:
# 6

# %%
f(3.5)
# Out:
# 7.0

# %%
f(5.5)
# Out:
# 11.0

# %%
methods(f)
# Out:
# # 1 method for generic function "f":
# f(x) at In[33]:1

# %%
@code_lowered f(3)
# Out:
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, {:x}, {{},{{:x,:Any,0}},{}}, :(begin  # In[33], line 1:
#         return 2x
#     end))))

# %%
@code_typed f(3)
# Out:
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, {:x}, {{},{{:x,Int64,0}},{}}, :(begin  # In[33], line 1:
#         return (top(box))(Int64,(top(mul_int))(2,x::Int64))::Int64
#     end::Int64))))

# %%
@code_typed f(3.5)
# Out:
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, {:x}, {{},{{:x,Float64,0}},{}}, :(begin  # In[33], line 1:
#         return (top(box))(Float64,(top(mul_float))((top(box))(Float64,(top(sitofp))(Float64,2))::Float64,x::Float64))::Float64
#     end::Float64))))

# %%
@code_llvm f(3)
# Out:
# define i64 @julia_f_21131(i64) {
# top:
#   %1 = shl i64 %0, 1, !dbg !3560
#   ret i64 %1, !dbg !3560
# }

# %%
@code_llvm f(3.5)
# Out:
# define double @julia_f_21155(double) {
# top:
#   %1 = fmul double %0, 2.000000e+00, !dbg !3627
#   ret double %1, !dbg !3627
# }

# %%
@code_native f(3)
# Out:
# 	.section	__TEXT,__text,regular,pure_instructions
# Filename: In[33]
# Source line: 1
# 	push	RBP
# 	mov	RBP, RSP
# Source line: 1
# 	lea	RAX, QWORD PTR [RDI + RDI]
# 	pop	RBP
# 	ret

# %%
@code_native f(3.5)
# Out:
# 	.section	__TEXT,__text,regular,pure_instructions
# Filename: In[33]
# Source line: 1
# 	push	RBP
# 	mov	RBP, RSP
# Source line: 1
# 	vaddsd	XMM0, XMM0, XMM0
# 	pop	RBP
# 	ret

# %%
@code_native big(10)^20
# Out:
# 	.section	__TEXT,__text,regular,pure_instructions
# Filename: gmp.jl
# Source line: 358
# 	push	RBP
# 	mov	RBP, RSP
# Source line: 358
# 	movabs	RAX, 4379751728
# 	call	RAX
# 	pop	RBP
# 	ret

# %%
big(10^20)
# Out:
# 7766279631452241920

# %%
^
# Out:
# ^ (generic function with 45 methods)

# %%
methods(^)
# Out:
# # 45 methods for generic function "^":
# ^(x::Bool,y::Bool) at bool.jl:42
# ^(x::BigInt,y::Bool) at gmp.jl:357
# ^(x::Integer,y::Bool) at bool.jl:43
# ^{T<:FloatingPoint}(z::Complex{T<:FloatingPoint},p::Complex{T<:FloatingPoint}) at complex.jl:401
# ^{T<:Complex{T<:Real}}(z::T<:Complex{T<:Real},p::T<:Complex{T<:Real}) at complex.jl:448
# ^{T<:FloatingPoint}(z::Complex{T<:FloatingPoint},n::Bool) at complex.jl:510
# ^{T<:Integer}(z::Complex{T<:Integer},n::Bool) at complex.jl:511
# ^{T<:Rational{T<:Integer}}(z::Complex{T<:Rational{T<:Integer}},n::Bool) at rational.jl:181
# ^(z::Complex{T<:Real},n::Bool) at complex.jl:507
# ^{T<:FloatingPoint}(z::Complex{T<:FloatingPoint},n::Integer) at complex.jl:513
# ^{T<:Integer}(z::Complex{T<:Integer},n::Integer) at complex.jl:515
# ^{T<:Rational{T<:Integer}}(z::Complex{T<:Rational{T<:Integer}},n::Integer) at rational.jl:182
# ^(z::Complex{T<:Real},n::Integer) at complex.jl:508
# ^(x::Rational{T<:Integer},y::Integer) at rational.jl:174
# ^{T<:FloatingPoint}(x::T<:FloatingPoint,y::Rational{T<:Integer}) at rational.jl:178
# ^{T<:FloatingPoint}(x::Complex{T<:FloatingPoint},y::Rational{T<:Integer}) at rational.jl:179
# ^(::MathConst{:e},x::Rational{T<:Integer}) at constants.jl:74
# ^(x::Number,y::Rational{T<:Integer}) at rational.jl:177
# ^(x::BigInt,y::Uint64) at gmp.jl:343
# ^(x::BigInt,y::BigInt) at gmp.jl:356
# ^(x::BigInt,y::Integer) at gmp.jl:358
# ^(x::Integer,y::BigInt) at gmp.jl:359
# ^{T<:Integer}(x::T<:Integer,p::T<:Integer) at intfuncs.jl:84
# ^(x::Float64,y::Integer) at math.jl:257
# ^(x::Float32,y::Integer) at math.jl:259
# ^(x::Float16,y::Integer) at float16.jl:148
# ^(x::BigFloat,y::Union(Uint32,Uint64,Uint16,Uint8)) at mpfr.jl:305
# ^(x::BigFloat,y::Union(Int16,Int64,Int32,Int8)) at mpfr.jl:311
# ^(x::BigFloat,y::BigInt) at mpfr.jl:317
# ^(::MathConst{:e},x::Integer) at constants.jl:74
# ^(x::Number,p::Integer) at intfuncs.jl:85
# ^(x::Float64,y::Float64) at math.jl:254
# ^(x::Float32,y::Float32) at math.jl:255
# ^(a::Float16,b::Float16) at float16.jl:132
# ^(x::BigFloat,y::BigFloat) at mpfr.jl:299
# ^(::MathConst{:e},x::MathConst{sym}) at constants.jl:74
# ^(x::MathConst{sym},y::MathConst{sym}) at constants.jl:23
# ^(::MathConst{:e},x::Number) at constants.jl:74
# ^{T<:Number}(x::T<:Number,y::T<:Number) at promotion.jl:192
# ^(x::Number,y::Number) at promotion.jl:162
# ^(s::String,r::Integer) at string.jl:77
# ^(A::Array{T,2},p::Integer) at linalg/dense.jl:156
# ^(x,p::Integer) at intfuncs.jl:86
# ^(A::Array{T,2},p::Number) at linalg/dense.jl:159
# ^(::MathConst{:e},x::AbstractArray{T,2}) at constants.jl:79

# %%
@which 10^20
# Out:
# ^{T<:Integer}(x::T<:Integer,p::T<:Integer) at intfuncs.jl:84

# %%
@which big(10)^20
# Out:
# ^(x::BigInt,y::Integer) at gmp.jl:358

# %%
g(x) = 3x^2
# Out:
# g (generic function with 1 method)

# %%
@time g(10)
# Out:
# elapsed time: 0.001462295 seconds (32224 bytes allocated)
# 300

# %%
@time g(10)
# Out:
# elapsed time: 2.873e-6 seconds (80 bytes allocated)
# 300

# %%
@time g(3.5)
# Out:
# elapsed time: 0.001406807 seconds (35044 bytes allocated)
# 36.75

# %%
@time g(3.5)
# Out:
# elapsed time: 2.858e-6 seconds (96 bytes allocated)
# 36.75

# %%
@code_llvm g(3)
# Out:
# define i64 @julia_g_21215(i64) {
# top:
#   %1 = mul i64 %0, 3, !dbg !3809
#   %2 = mul i64 %1, %0, !dbg !3809
#   ret i64 %2, !dbg !3809
# }

# %%
@code_llvm g(10)
# Out:
# define i64 @julia_g_21216(i64) {
# top:
#   %1 = mul i64 %0, 3, !dbg !3812
#   %2 = mul i64 %1, %0, !dbg !3812
#   ret i64 %2, !dbg !3812
# }

# %%
@code_llvm g(20)
# Out:
# define i64 @julia_g_21217(i64) {
# top:
#   %1 = mul i64 %0, 3, !dbg !3815
#   %2 = mul i64 %1, %0, !dbg !3815
#   ret i64 %2, !dbg !3815
# }

# %% [markdown]
# # Vecteurs

# %%
v = [1]
# Out:
# 1-element Array{Int64,1}:
#  1

# %%
push!(v, 3.5)
# Out:
# InexactError()
# while loading In[62], in expression starting on line 1
#
#  in push! at array.jl:460

# %%
w = Any[]
# Out:
# 0-element Array{Any,1}

# %%
w = [3, 4.5, "David"]
# Out:
# 3-element Array{Any,1}:
#  3
#  4.5
#   "David"

# %%
z = [3, 3.5]
# Out:
# 2-element Array{Float64,1}:
#  3.0
#  3.5

# %%
push!(w, [3, 4])
# Out:
# 4-element Array{Any,1}:
#  3
#  4.5
#   "David"
#   [3,4]

# %%
push!(w, w)
# Out:
# stack overflow
#
#  in print_to_string at string.jl:21
#  in string at string.jl:31
#  in array_eltype_show_how at show.jl:1171
#  in show_vector at show.jl:1180
#  in show at show.jl:1194
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
# ...
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148
#  in show_vector at show.jl:1189
#  in show at show.jl:1193
#  in show_delim_array at show.jl:148

# %%
Vector{Int64} == Array{Int64, 1}
# Out:
# true
